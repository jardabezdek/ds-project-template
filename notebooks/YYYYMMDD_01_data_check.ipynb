# %% [markdown]
# ## In this notebook
#
# - Check data.

# %%
import os

# analytics
import pandas as pd
pd.set_option("display.max_rows", 100)
pd.set_option("display.max_columns", 100)
import numpy as np

# plot
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
DATA_FOLDER = "../data"
DATA_FILEPATH = "../data/sample.csv"

# %%
! ls -l $DATA_FOLDER
# Out:
# total 4
# -rw-r--r-- 1 nobody nogroup 20 Dec 20 20:42 sample.csv

# %% [markdown]
# ## Load data

# %%
# %%time

df = (
    pd
    .read_csv(DATA_FILEPATH)
)

df.tail()
# Out:
# CPU times: user 4.58 ms, sys: 4.2 ms, total: 8.77 ms
# Wall time: 6.84 ms
#    col_A  col_B
# 0      1      2
# 1      3      4

# %%
# create plot

ax = df.col_A.plot()

ax.set_xlabel("X axis label")
ax.set_ylabel("Y axis label")
ax.set_title("Plot title")

plt.show()

# %% [markdown]
# ## Results
#
# - Checked data.
# - Created plot.
